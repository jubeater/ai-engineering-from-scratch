# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>WMRN-S4Z0</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>jubeater</b> (token: <code>oauth-jubeater</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
from transformers import AutoModel

model = AutoModel.from_pretrained("meta-llama/Llama-2-7b-hf")
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:795, in hf_raise_for_status(response, endpoint_name)
#     794 try:
# --> 795     response.raise_for_status()
#     796 except httpx.HTTPStatusError as e:
#
# File /opt/venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File /opt/venv/lib/python3.12/site-packages/transformers/utils/hub.py:437, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     435 if len(full_filenames) == 1:
#     436     # This is slightly better for only 1 file
# --> 437     hf_hub_download(
#     438         path_or_repo_id,
#     439         filenames[0],
#     440         subfolder=None if len(subfolder) == 0 else subfolder,
#     441         repo_type=repo_type,
#     442         revision=revision,
#     443         cache_dir=cache_dir,
#     444         user_agent=user_agent,
#     445         force_download=force_download,
#     446         proxies=proxies,
#     447         token=token,
#     448         local_files_only=local_files_only,
#     449         tqdm_class=tqdm_class,
#     450     )
#     451 else:
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1013, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#    1012 else:
# -> 1013     return _hf_hub_download_to_cache_dir(
#    1014         # Destination
#    1015         cache_dir=cache_dir,
#    1016         # File info
#    1017         repo_id=repo_id,
#    1018         filename=filename,
#    1019         repo_type=repo_type,
#    1020         revision=revision,
#    1021         # HTTP info
#    1022         endpoint=endpoint,
#    1023         etag_timeout=etag_timeout,
#    1024         headers=hf_headers,
#    1025         token=token,
#    1026         # Additional options
#    1027         local_files_only=local_files_only,
#    1028         force_download=force_download,
#    1029         tqdm_class=tqdm_class,
#    1030         dry_run=dry_run,
#    1031     )
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1165, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1164     if head_call_error is not None:
# -> 1165         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1167 # From now on, etag, commit_hash, url and size are not None.
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1864, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1859 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1860     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1861 ):
#    1862     # Repo not found or gated => let's raise the actual error
#    1863     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1864     raise head_call_error
#    1865 else:
#    1866     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1707, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors, tree_cache_folder)
#    1706 try:
# -> 1707     metadata = get_hf_file_metadata(
#    1708         url=url,
#    1709         timeout=etag_timeout,
#    1710         headers=headers,
#    1711         token=token,
#    1712         endpoint=endpoint,
#    1713         retry_on_errors=retry_on_errors,
#    1714     )
#    1715 except RemoteEntryNotFoundError as http_error:
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:1615, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1614 # Retrieve metadata
# -> 1615 response = _httpx_follow_relative_redirects_with_backoff(
#    1616     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1617 )
#    1618 hf_raise_for_status(response)
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:726, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     719 response = http_backoff(
#     720     method=method,
#     721     url=url,
#    (...)    724     **no_retry_kwargs,
#     725 )
# --> 726 hf_raise_for_status(response)
#     728 # Check if response is a relative redirect
#
# File /opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py:821, in hf_raise_for_status(response, endpoint_name)
#     818     message = (
#     819         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     820     )
# --> 821     raise _format(GatedRepoError, message, response, repo_type=repo_type, repo_id=repo_id) from e
#     823 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 403 Client Error. (Request ID: Root=1-6a5ef70a-2372c9d716775a1a5ff0e194;980908bd-730b-4290-95a1-4cf71288b471)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-hf to ask for access.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 from transformers import AutoModel
#       2
# ----> 3 model = AutoModel.from_pretrained("meta-llama/Llama-2-7b-hf")
#
# File /opt/venv/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:336, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     333 if kwargs.get("quantization_config") is not None:
#     334     _ = kwargs.pop("quantization_config")
# --> 336 config, kwargs = AutoConfig.from_pretrained(
#     337     pretrained_model_name_or_path,
#     338     return_unused_kwargs=True,
#     339     code_revision=code_revision,
#     340     _commit_hash=commit_hash,
#     341     **hub_kwargs,
#     342     **kwargs,
#     343 )
#     345 # A concrete dtype is absorbed into the config above and then dropped at the composite
#     346 # `get_text_config()` swap, so re-inject the user's value as an explicit kwarg to force the model's
#     347 # `from_pretrained` to honor it over the config's saved dtype (#46459).
#     348 if kwargs_orig.get("torch_dtype", None) is not None:
#
# File /opt/venv/lib/python3.12/site-packages/transformers/models/auto/configuration_auto.py:376, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     373 trust_remote_code = kwargs.pop("trust_remote_code", None)
#     374 code_revision = kwargs.pop("code_revision", None)
# --> 376 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     377 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     378 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File /opt/venv/lib/python3.12/site-packages/transformers/configuration_utils.py:721, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     719 original_kwargs = copy.deepcopy(kwargs)
#     720 # Get config dict associated with the base config file
# --> 721 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     722 if config_dict is None:
#     723     return {}, kwargs
#
# File /opt/venv/lib/python3.12/site-packages/transformers/configuration_utils.py:776, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     772 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     774 try:
#     775     # Load from local folder or from cache or download from model Hub and cache
# --> 776     resolved_config_file = cached_file(
#     777         pretrained_model_name_or_path,
#     778         configuration_file,
#     779         cache_dir=cache_dir,
#     780         force_download=force_download,
#     781         proxies=proxies,
#     782         local_files_only=local_files_only,
#     783         token=token,
#     784         user_agent=user_agent,
#     785         revision=revision,
#     786         subfolder=subfolder,
#     787         _commit_hash=commit_hash,
#     788     )
#     789     if resolved_config_file is None:
#     790         return None, kwargs
#
# File /opt/venv/lib/python3.12/site-packages/transformers/utils/hub.py:293, in cached_file(path_or_repo_id, filename, **kwargs)
#     238 def cached_file(
#     239     path_or_repo_id: str | os.PathLike,
#     240     filename: str,
#     241     **kwargs,
#     242 ) -> str | None:
#     243     """
#     244     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     245
#    (...)    291     ```
#     292     """
# --> 293     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     294     file = file[0] if file is not None else file
#     295     return file
#
# File /opt/venv/lib/python3.12/site-packages/transformers/utils/hub.py:503, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     501     if not _raise_exceptions_for_gated_repo:
#     502         return None
# --> 503     raise OSError(
#     504         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     505         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     506     ) from e
#     507 elif isinstance(e, LocalEntryNotFoundError):
#     508     if not _raise_exceptions_for_connection_errors:
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-2-7b-hf.
# 403 Client Error. (Request ID: Root=1-6a5ef70a-2372c9d716775a1a5ff0e194;980908bd-730b-4290-95a1-4cf71288b471)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json.
# Access to model meta-llama/Llama-2-7b-hf is restricted and you are not in the authorized list. Visit https://huggingface.co/meta-llama/Llama-2-7b-hf to ask for access.
